# %%
import os
import time
import sys
import random
import urllib
import urllib.request

while True:
    senval1= random.randrange(0,50)
    print(senval1)
    senval2= random.randrange(0,50)
    print(senval2)
    senval3= random.randrange(0,50)
    print(senval3)
    senval4= random.randrange(0,50)
    print(senval4)
    senval5= random.randrange(0,50)
    print(senval5)
    b=urllib.request.urlopen('https://api.thingspeak.com/update?api_key=Z6OA6EHL6B6KH6GR&field1=' + str(senval1)+';field2='+str(senval2)+';field2='+str(senval2)+';field3='+str(senval3)+';field4='+str(senval4)+';field5='+str(senval5))
    print(b.read())
    time.sleep(5)
print('end')
# Out:
# 14
# 8
# 47
# 40
# 27
# b'1'
# 34
# 34
# 5
# 47
# 46
# b'0'
# 0
# 46
# 49
# 6
# 8
# b'0'
# 8
# 6
# 18
# 24
# 8
# b'2'
# 8
# 29
# 49
# 28
# 46
# b'0'
# 43
# 48
# 17
# 15
# 29
# b'0'
# 29
# 4
# 45
# 38
# 42
# b'3'
# 35
# 34
# 35
# 26
# 24
# b'0'
# 1
# 45
# 33
# 22
# 6
# b'0'
# 42
# 30
# 0
# 21
# 49
# b'4'
# 4
# 36
# 44
# 40
# 48
# b'0'
# 2
# 15
# 21
# 16
# 10
# b'0'
# 22
# 16
# 21
# 43
# 10
# b'5'
# 28
# 32
# 49
# 40
# 42
# b'0'
# 20
# 18
# 21
# 13
# 32
# b'0'
# 40
# 26
# 38
# 28
# 27
# b'6'
# 30
# 12
# 42
# 39
# 40
# b'0'
# 41
# 30
# 31
# 2
# 31
# b'0'
# 2
# 13
# 27
# 27
# 4
# b'7'
# 21
# 46
# 47
# 13
# 7
# b'0'
# 43
# 21
# 35
# 21
# 44
# b'0'
# 16
# 5
# 38
# 40
# 39
# b'8'
# 34
# 18
# 37
# 22
# 38
# b'0'
# 24
# 40
# 3
# 11
# 34
# b'0'
# 38
# 33
# 18
# 38
# 3
# b'9'
# 40
# 31
# 7
# 18
# 8
# b'0'
# 5
# 6
# 46
# 4
# 48
# b'0'
# 36
# 4
# 32
# 30
# 3
# b'10'
# 16
# 35
# 44
# 20
# 46
# b'0'
# 14
# 1
# 20
# 28
# 47
# b'0'
# 13
# 20
# 21
# 48
# 20
# b'11'
# 43
# 35
# 24
# 33
# 6
# b'0'
# 4
# ...

# %%
import pandas as pd
import matplotlib as plt
import os
import time
import sys
import random
import urllib
import urllib.request

# %%
df = pd.read_csv(r'C:\Users\anany\Downloads\feed.csv')
print(df)
# Out:
#                  created_at  entry_id  field1  field2  field3  field4  field5  \
# 0   2022-02-09 15:41:47 UTC         1      14       8      47      40      27
# 1   2022-02-09 15:42:06 UTC         2       8       6      18      24       8
# 2   2022-02-09 15:42:25 UTC         3      29       4      45      38      42
# 3   2022-02-09 15:42:44 UTC         4      42      30       0      21      49
# 4   2022-02-09 15:43:03 UTC         5      22      16      21      43      10
# ..                      ...       ...     ...     ...     ...     ...     ...
# 59  2022-02-09 16:00:42 UTC        60      19       1      36      39      12
# 60  2022-02-09 16:01:01 UTC        61      35      46       4       2      32
# 61  2022-02-09 16:01:20 UTC        62       1      14      31      48      48
# 62  2022-02-09 16:01:40 UTC        63      31      48      27      31       5
# 63  2022-02-09 16:01:59 UTC        64      17       1       7       3      30
#
#     field6
# 0      NaN
# ...

# %%
df = pd.read_csv(r'C:\Users\anany\Downloads\feed.csv')
df_mean1 = df["field1"].mean()
df_mean2 = df["field2"].mean()
df_mean3 = df["field3"].mean()
df_mean_soil=(df["field1"].mean()+df["field1"].mean()+df["field1"].mean())/3
print("mean of soil moisture is ", df_mean_soil)
# Out:
# mean of soil moisture is  22.953125

# %%
if(df_mean1>=50):
 senval1=0
 print("motor 1 is off")
else:
 senval1=1
 print("motor 1 is on")
if(df_mean2>=50):
 senval2=0
 print("motor 2 is off")
else:
 senval2=1
 print("motor 2 is on")
if(df_mean3>=50):
 senval3=0
 print("motor 3 is off")
else:
 senval3=1
 print("motor 3 is on")
# Out:
# motor 1 is on
# motor 2 is on
# motor 3 is on

# %%
df_mean1 = df["field1"].mean()
df_mean2 = df["field2"].mean()
df_mean3 = df["field3"].mean()
df_mean_soil=(df["field1"].mean()+df["field1"].mean()+df["field1"].mean())/3
print(df_mean_soil)
# Out:
# 22.953125

# %%
df.corr()
# Out:
#           entry_id    field1    field2    field3    field4    field5  field6
# entry_id  1.000000 -0.038898  0.143853  0.005157 -0.156871 -0.009662     NaN
# field1   -0.038898  1.000000  0.107891 -0.024496 -0.108360  0.132546     NaN
# field2    0.143853  0.107891  1.000000 -0.104391 -0.104675  0.211214     NaN
# field3    0.005157 -0.024496 -0.104391  1.000000  0.134608  0.004045     NaN
# field4   -0.156871 -0.108360 -0.104675  0.134608  1.000000  0.153367     NaN
# field5   -0.009662  0.132546  0.211214  0.004045  0.153367  1.000000     NaN
# field6         NaN       NaN       NaN       NaN       NaN       NaN     NaN

# %%
import os
import time
import sys
import random
import urllib
import urllib.request

while True:
    senval1= random.randrange(0,100)
    print(senval1)
    senval2= random.randrange(0,100)
    print(senval2)
    senval3= random.randrange(0,100)
    print(senval3)
    senval4= random.randrange(0,100)
    print(senval4)
    senval5= random.randrange(0,100)
    print(senval5)
    b=urllib.request.urlopen('https://api.thingspeak.com/update?api_key=Z6OA6EHL6B6KH6GR&field1=' + str(senval1)+';field2='+str(senval2)+';field2='+str(senval2)+';field3='+str(senval3)+';field4='+str(senval4)+';field5='+str(senval5))
    print(b.read())
    time.sleep(5)
print('end')
# Out:
# 81
# 9
# 78
# 77
# 13
# b'88'
# 88
# 30
# 94
# 38
# 4
# b'0'
# 58
# 23
# 61
# 23
# 46
# b'0'
# 1
# 8
# 96
# 67
# 68
# b'89'
# 3
# 25
# 3
# 65
# 27
# b'0'
# 8
# 38
# 24
# 41
# 97
# b'0'
# 66
# 73
# 67
# 75
# 67
# b'90'
# 26
# 73
# 55
# 20
# 43
# b'0'
# 44
# 89
# 76
# 69
# 27
# b'0'
# 64
# 63
# 13
# 45
# 82
# b'91'
# 6
# 1
# 44
# 53
# 35
# b'0'
# 96
# 96
# 84
# 16
# 15
# b'0'
# 83
# 36
# 49
# 61
# 49
# b'92'
# 27
# 15
# 34
# 21
# 67
# b'0'
# 78
# 81
# 24
# 52
# 97
# b'0'
# 11
# 9
# 84
# 22
# 50
# b'93'
# 30
# 15
# 30
# 33
# 12
# b'0'
# 40
# 85
# 77
# 94
# 8
# b'0'
# 88
# 42
# 67
# 70
# 39
# b'94'
# 78
# 87
# 79
# 10
# 3
# b'0'
# 45
# 28
# 15
# 78
# 75
# b'0'
# 75
# 90
# 95
# 48
# 19
# b'95'
# 59
# 77
# 75
# 39
# 8
# b'0'
# 62
# 82
# 1
# 96
# 58
# b'0'
# 59
# 91
# 80
# 32
# 84
# b'96'
# 34
# 40
# 30
# 19
# 31
# b'0'
# 29
# 37
# 96
# 21
# 57
# b'0'
# 52
# 31
# 90
# 77
# 73
# b'97'
# 43
# 5
# 97
# 2
# 21
# b'0'
# 71
# 8
# 31
# 97
# 4
# b'0'
# 5
# 93
# 97
# 72
# 60
# b'98'
# 77
# 19
# 62
# ...
